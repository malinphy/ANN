# %%
import numpy as np
import pandas as pd
# !pip install --quiet scann
from sklearn import preprocessing
from sklearn.metrics.pairwise import cosine_similarity

# %%
import scann

# %%
# selected_col=['age' ,'overall','potential','international_reputation',	'skill_moves' ,'weak_foot','nation_jersey_number',	'pace' ,'shooting' ,'passing' ,'dribbling','defending',	'physic' ,'gk_diving' ,'gk_handling' ,'gk_kicking','gk_reflexes' ,'gk_speed',	'gk_positioning' ,'attacking_crossing',	'attacking_finishing' ,'attacking_heading_accuracy' ,'attacking_short_passing' ,'attacking_volleys' ,'skill_dribbling',	'skill_curve' ,'skill_fk_accuracy' ,'skill_long_passing'	,'skill_ball_control' ,'movement_acceleration','movement_sprint_speed',	'movement_agility',	'movement_reactions' ,'movement_balance',	'power_shot_power' ,'power_jumping',	'power_stamina'	,'power_strength' ,'power_long_shots' ,'mentality_aggression' ,'mentality_interceptions',	'mentality_positioning' ,'mentality_vision' ,	'mentality_penalties' ,'mentality_composure','defending_marking' ,'defending_standing_tackle' ,'defending_sliding_tackle',	'goalkeeping_diving' 	,'goalkeeping_handling' ,'goalkeeping_kicking' ,'goalkeeping_positioning' ,'goalkeeping_reflexes' ,'ls' ,'st' ,'rs' ,'lw','lf' ,'cf' ,'rf' ,'rw' ,'lam' ,'cam','ram' ,'lm' ,'lcm' ,'cm' ,'rcm','rm' ,'lwb','ldm' ,'cdm' ,'rdm' ,'rwb','lb','lcb','cb' ,'rcb','rb']
selected_col=['short_name','age' ,'overall','potential','international_reputation',	'skill_moves' ,'weak_foot','nation_jersey_number','pace',
              'shooting','passing','dribbling']# 'dribbling','defending',	'physic' ,'gk_diving' ,'gk_handling' ,'gk_kicking','gk_reflexes' ,'gk_speed',	'gk_positioning' ,'attacking_crossing',	'attacking_finishing' ,'attacking_heading_accuracy' ,'attacking_short_passing' ,'attacking_volleys' ,'skill_dribbling',	'skill_curve' ,'skill_fk_accuracy' ,'skill_long_passing'	,'skill_ball_control' ,'movement_acceleration','movement_sprint_speed',	'movement_agility',	'movement_reactions' ,'movement_balance',	'power_shot_power' ,'power_jumping',	'power_stamina'	,'power_strength' ,'power_long_shots' ,'mentality_aggression' ,'mentality_interceptions',	'mentality_positioning' ,'mentality_vision' ,	'mentality_penalties' ,'mentality_composure','defending_marking' ,'defending_standing_tackle' ,'defending_sliding_tackle',	'goalkeeping_diving' 	,'goalkeeping_handling' ,'goalkeeping_kicking' ,'goalkeeping_positioning' ,'goalkeeping_reflexes' ,'ls' ,'st' ,'rs' ,'lw','lf' ,'cf' ,'rf' ,'rw' ,'lam' ,'cam','ram' ,'lm' ,'lcm' ,'cm' ,'rcm','rm' ,'lwb','ldm' ,'cdm' ,'rdm' ,'rwb','lb','lcb','cb' ,'rcb','rb']

# %%
url = 'https://raw.githubusercontent.com/malinphy/datasets/main/fifa/players_15.csv'
df = pd.read_csv(url, 
                 usecols = selected_col
                 ).dropna(axis=0)

# %%
df
# Out:
#               short_name  age  overall  potential  international_reputation  \
# 0               L. Messi   27       93         95                         5
# 1      Cristiano Ronaldo   29       92         92                         5
# 2              A. Robben   30       90         90                         5
# 3         Z. Ibrahimović   32       90         90                         5
# 6              E. Hazard   23       88         90                         4
# ...                  ...  ...      ...        ...                       ...
# 14283      S. Rahim Nabi   28       54         54                         1
# 14489         S. Pradhan   24       53         58                         1
# 14770         J. Stevens   19       52         56                         1
# 14772          R. Lamare   27       52         55                         1
# 14982        D. Bejarano   22       51         54                         1
#
# ...

# %%
df_np = preprocessing.normalize(df.iloc[:,1:-1])

# %%
df.iloc[:,1:-1]
# Out:
#        age  overall  potential  international_reputation  weak_foot  \
# 0       27       93         95                         5          3
# 1       29       92         92                         5          4
# 2       30       90         90                         5          2
# 3       32       90         90                         5          4
# 6       23       88         90                         4          4
# ...    ...      ...        ...                       ...        ...
# 14283   28       54         54                         1          3
# 14489   24       53         58                         1          3
# 14770   19       52         56                         1          3
# 14772   27       52         55                         1          3
# 14982   22       51         54                         1          2
#
#        skill_moves  nation_jersey_number  pace  shooting  passing
# 0                4                  10.0  93.0      89.0     86.0
# ...

# %%
df_np.shape
# Out:
# (918, 10)

# %%
df.shape
# Out:
# (918, 12)

# %%
k = int(np.sqrt(df_np.shape[0]))

# %%
searcher = scann.scann_ops_pybind.builder(df_np, 10, "dot_product").tree(
    num_leaves=k, num_leaves_to_search=int(k/20), training_sample_size=2500).score_brute_force(2).reorder(7).build()

# querying the searcher

# %%
df[df.short_name == 'A. Robben']
# Out:
#   short_name  age  overall  potential  international_reputation  weak_foot  \
# 2  A. Robben   30       90         90                         5          2
#
#    skill_moves  nation_jersey_number  pace  shooting  passing  dribbling
# 2            4                  11.0  93.0      86.0     83.0       92.0

# %%
df[df.short_name == 'A. Robben']
# Out:
#   short_name  age  overall  potential  international_reputation  weak_foot  \
# 2  A. Robben   30       90         90                         5          2
#
#    skill_moves  nation_jersey_number  pace  shooting  passing  dribbling
# 2            4                  11.0  93.0      86.0     83.0       92.0

# %%
df_q = df[df.short_name == 'A. Robben']
df_q
# Out:
#   short_name  age  overall  potential  international_reputation  weak_foot  \
# 2  A. Robben   30       90         90                         5          2
#
#    skill_moves  nation_jersey_number  pace  shooting  passing  dribbling
# 2            4                  11.0  93.0      86.0     83.0       92.0

# %%
np_q = preprocessing.normalize(df_q.iloc[:,1:-1])

# %%
neighbors, distances = searcher.search(np_q[0], final_num_neighbors=20)

# %%
q_df = df.iloc[neighbors, :]

# %%
q_df.index = q_df['short_name']

# %%
q_df['distance'] = list(distances)
q_df['distance']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# short_name
# A. Robben            1.000000
# Vieirinha            0.999734
# M. Erdinç            0.999668
# J. Farfán            0.999658
# S. Kalou             0.999635
# O. Şahan             0.999630
# M. Harnik            0.999590
# K. Mirallas          0.999498
# S. Naismith          0.999475
# B. Dzsudzsák         0.999469
# M. Fabián            0.999396
# A. Kokorin           0.999390
# Éder                 0.999344
# K. Benzema           0.999344
# A. Kerzhakov         0.999340
# E. Choupo-Moting     0.999277
# V. Pilař             0.999200
# ...

# %%
sim_score = []
for x in df_np:
    sim_score.append(
        cosine_similarity(x.reshape(-1, 1), np_q.reshape(-1, 1)).mean())

# %%
df['distance'] = sim_score

# %%
df_sort = df.sort_values(by=['distance'], ascending=False)

# %%
df_sort.index = df_sort['short_name']

# %%
df_sort['distance'].head(10)
# Out:
# short_name
# L. Messi        1.0
# J. Toivio       1.0
# A. Søderlund    1.0
# H. Ayala        1.0
# M. Ponce        1.0
# O. Martenosa    1.0
# M. Bresciano    1.0
# A. Reid         1.0
# S. Whittaker    1.0
# R. Würtz        1.0
# Name: distance, dtype: float64
